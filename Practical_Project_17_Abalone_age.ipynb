# %% [markdown]
# import all necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# C:\Users\avani\Anaconda\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %% [markdown]
# read csv file

# %%
df = pd.read_csv('abalone.csv')

# %% [markdown]
# it gives all the necessary information regarding the dataset,
# such as dataset size, datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# first five dataset values

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# it tells about the missing value of each attributes

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# 'nlargest' gives the largest value of the given column

# %%
df.nlargest(5,'Rings')
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 480    F   0.700     0.585   0.185        1.8075          0.7055
# 2108   M   0.665     0.535   0.225        2.1835          0.7535
# 2209   F   0.550     0.465   0.180        1.2125          0.3245
# 294    M   0.600     0.495   0.195        1.0575          0.3840
# 2201   F   0.645     0.490   0.215        1.4060          0.4265
#
#       Viscera weight  Shell weight  Rings
# 480           0.3215         0.475     29
# 2108          0.3910         0.885     27
# 2209          0.2050         0.525     27
# 294           0.1900         0.375     26
# 2201          0.2285         0.510     25

# %% [markdown]
# converting the categorical through the numerical value,
# assigning integer to each type of value

# %%
df['Sex'] = pd.factorize(df['Sex'])[0]

# %% [markdown]
# it shows 'M' :0, 'F':1, 'I':2

# %%
df['Sex'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    2
# Name: Sex, dtype: int64

# %% [markdown]
# Assigning the independent value to X and dependent value to y

# %%
X = df.iloc[:,1:-1]
y = df.iloc[:,-1]

# %%
X.head()
y.head()
# Out:
# 0    15
# 1     7
# 2     9
# 3    10
# 4     7
# Name: Rings, dtype: int64

# %% [markdown]
# split the data into training and validation sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= 0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
# create an estimator, optionally specifying parameters
model = DecisionTreeRegressor()
# fit the estimator to the data
model.fit(X_train, y_train)
# apply the model to the test and training data
predicted_test_y = model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.20676006043560236

# %%
from sklearn.ensemble import RandomForestRegressor
model_r = RandomForestRegressor(n_estimators=100)
model_r.fit(X_train, y_train)
y_pred = model_r.predict(X_test)
model_r.score(X_test,y_test)
# Out:
# 0.5620564147480156

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_ = log.predict(X_test)
log.score(X_test,y_test)
# Out:
# 0.794180269694819

# %%
from sklearn.metrics import accuracy_score
print (accuracy_score(y_test,y_pred_))
# Out:
# 0.794180269694819

# %%
from sklearn.ensemble import RandomForestClassifier
ran = RandomForestClassifier()
ran.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = ran.predict(X_test)
ran.score(X_test,y_test)
# Out:
# 0.7672107877927609

# %%
from sklearn.ensemble import RandomForestClassifier
ran = RandomForestClassifier(criterion = 'entropy')
ran.fit(X_train,y_train)
y_predd = ran.predict(X_test)
ran.score(X_test,y_test)
# Out:
# 0.7714691270404542
